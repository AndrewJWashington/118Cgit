# %% [markdown]
# # COGS 118C Assignment 3

# %% [markdown]
# An exploration by Andrew Washington

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
T = 60 # seconds
Fs = 60 # Hz
x = np.arange(0, T, 1/Fs)
F = np.sin(2*np.pi*2*x) + 1.5*np.sin(2*np.pi*x*2.3)

plt.figure(figsize=(15,4))
plt.gca().set_xlim(0,30)
plt.plot(x, F)

# %%
#FIXME: calculate gaussian params such that SNR=10dB
noise = np.random.normal(0, 0.75, len(x)) # params: mean, stdev, array size
F = F + noise

plt.figure(figsize=(15,4))
plt.gca().set_xlim(0,30)
plt.plot(x, F)
